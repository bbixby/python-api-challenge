# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
#install from command line before opening jupyter notebook as 'pip install citipy'
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url for query with imperial units and city at the end
url = "http://api.openweathermap.org/data/2.5/weather?id=524901"
unit = "imperial"
query_url = f"{url}&appid={weather_api_key}&units={unit}&q="

# Lists for results
lat = []
lon = []
foundCities = []
temp = []
humidity = []
cloudiness = []
windSpeed = []
date = []

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windSpeed.append(response["wind"]["speed"])
        date.append(response["dt"])
        foundCities.append(city)
        print(f"City processed: {city}")
    except:
        print(f"City NOT found: {city}")
# Out:
# City processed: mataura
# City processed: hilo
# City processed: albany
# City processed: bethel
# City processed: fare
# City processed: chokurdakh
# City processed: genhe
# City processed: margate
# City processed: faanui
# City processed: lebu
# City processed: wschowa
# City processed: cockburn town
# City processed: yerbogachen
# City processed: damme
# City processed: punta arenas
# City NOT found: amderma
# City processed: bluff
# City processed: larap
# City processed: swan hill
# City processed: mitsamiouli
# City processed: hermanus
# City processed: kodiak
# City NOT found: taolanaro
# City processed: kapaa
# City processed: koping
# City processed: cape town
# City processed: hami
# City NOT found: phrai bung
# City processed: souillac
# City processed: yellowknife
# City processed: port alfred
# City processed: ibotirama
# City processed: new norfolk
# City processed: callaway
# City processed: jodhpur
# City processed: tessalit
# City processed: oranjestad
# City processed: tokorozawa
# City processed: norman wells
# City processed: busselton
# City processed: rikitea
# City processed: pirovskoye
# City processed: qaanaaq
# City NOT found: attawapiskat
# City processed: chepo
# City processed: chapais
# City processed: pasighat
# City processed: ushuaia
# City processed: koronowo
# City processed: skjervoy
# City processed: hithadhoo
# City processed: vaini
# City processed: dodge city
# City processed: raudeberg
# City processed: berdigestyakh
# City processed: hasaki
# City processed: eldorado
# City processed: catemaco
# City NOT found: umzimvubu
# City processed: bengkulu
# City processed: amarante do maranhao
# City processed: sena madureira
# City processed: dikson
# City NOT found: vaitupu
# City processed: udachnyy
# City processed: coronel oviedo
# City processed: kurumkan
# City processed: namibe
# City NOT found: samalaeulu
# City processed: saint-francois
# City processed: clyde river
# City processed: kilindoni
# City NOT found: barentsburg
# City processed: bandarbeyla
# City processed: lixourion
# City processed: shubarkuduk
# City processed: longyearbyen
# City NOT found: crab hill
# City processed: pangkalanbuun
# City processed: newcastle
# City processed: necochea
# City processed: georgetown
# City processed: wuwei
# City NOT found: azar shahr
# City processed: salinas
# City processed: batagay-alyta
# City processed: saint-philippe
# City NOT found: saleaula
# City processed: partenit
# City processed: saskylakh
# City processed: ronne
# City processed: lashio
# City processed: tautira
# City processed: udimskiy
# City processed: puerto ayora
# City processed: carnarvon
# City processed: sakakah
# City processed: chuy
# City processed: port lincoln
# City processed: kinshasa
# City processed: atuona
# City NOT found: mys shmidta
# City processed: ust-maya
# City processed: beringovskiy
# City NOT found: palabuhanratu
# City processed: deori khas
# City processed: hobart
# City processed: pleszew
# City processed: bredasdorp
# City processed: esso
# City processed: polson
# City processed: victoria
# City processed: trat
# City processed: caravelas
# City processed: concordia
# City processed: airai
# City processed: cidreira
# City processed: barrow
# City processed: kavaratti
# City processed: aklavik
# City processed: saint-joseph
# City processed: san patricio
# City processed: jamestown
# City processed: kruisfontein
# City processed: khatanga
# City processed: saldanha
# City processed: quatre cocos
# City processed: mayumba
# City processed: ostrovnoy
# City processed: mezhdurechensk
# City processed: mahebourg
# City processed: butaritari
# City processed: itoman
# City NOT found: sentyabrskiy
# City processed: lagoa
# City processed: galle
# City processed: dzerzhinsk
# City processed: plettenberg bay
# City processed: ostrovskoye
# City processed: husavik
# City processed: mamu kanjan
# City processed: pudem
# City processed: dunedin
# City processed: stettler
# City processed: saint george
# City processed: deputatskiy
# City processed: toamasina
# City processed: esperance
# City processed: berlevag
# City processed: aykhal
# City processed: sisimiut
# City processed: castro
# City processed: yongan
# City processed: tilichiki
# City processed: east london
# City processed: coihaique
# City processed: bubaque
# City processed: atasu
# City processed: arraial do cabo
# City processed: constitucion
# City processed: dingle
# City processed: dubbo
# City processed: burgeo
# City processed: cabo san lucas
# City processed: sao filipe
# City NOT found: illoqqortoormiut
# City processed: lima
# City processed: cacheu
# City processed: ocos
# City processed: sakaraha
# City processed: mar del plata
# City processed: half moon bay
# City processed: klaksvik
# City processed: sitka
# City processed: luyang
# City processed: qiongshan
# City processed: castlerea
# City processed: tambovka
# City processed: kloulklubed
# City processed: sao joao da barra
# City processed: cherskiy
# City processed: inuvik
# City processed: alice springs
# City processed: yulara
# City processed: kwekwe
# City processed: touros
# City processed: atambua
# City processed: soyo
# City processed: tiznit
# City processed: bilma
# City processed: lompoc
# City processed: karachi
# City processed: iqaluit
# City processed: ordynskoye
# City processed: kamenka
# City processed: jacksonville
# City processed: tambacounda
# City processed: avarua
# City processed: yamada
# City processed: provideniya
# City processed: kita
# City processed: upernavik
# City processed: ust-nera
# City processed: ust-ilimsk
# City processed: wattegama
# City processed: marsh harbour
# City processed: pangai
# City processed: nikolskoye
# City processed: garmsar
# City processed: cabra
# City processed: umba
# City processed: sept-iles
# City NOT found: longlac
# City processed: jinchang
# City processed: minsk mazowiecki
# City processed: thompson
# City processed: kabanjahe
# City processed: north bend
# City processed: kirakira
# City processed: avera
# City processed: kathmandu
# City processed: sheridan
# City processed: asyut
# City NOT found: sorvag
# City processed: meulaboh
# City processed: quelimane
# City processed: launceston
# City processed: saint anthony
# City processed: tasiilaq
# City processed: ajdabiya
# City processed: goderich
# City processed: sorland
# City processed: flinders
# City processed: novo aripuana
# City processed: ati
# City processed: qandala
# City processed: kaitangata
# City processed: orsha
# City processed: ribeira grande
# City processed: tuktoyaktuk
# City processed: shizunai
# City processed: rawah
# City processed: safford
# City processed: pisco
# City processed: muros
# City processed: baykit
# City processed: wahiawa
# City processed: nanortalik
# City processed: port elizabeth
# City processed: paka
# City processed: bambous virieux
# City processed: ancud
# City processed: veraval
# City NOT found: belushya guba
# City processed: naze
# City processed: cochabamba
# City processed: inirida
# City processed: umm kaddadah
# City processed: te anau
# City processed: along
# City processed: rehoboth
# City processed: sao pedro do sul
# City processed: koslan
# City processed: bairiki
# City processed: rawson
# City processed: tianpeng
# City processed: qasigiannguit
# City processed: college
# City processed: praya
# City processed: marzuq
# City processed: ivanava
# City processed: zmeinogorsk
# City processed: isangel
# City processed: shingu
# City processed: salina
# City processed: talnakh
# City processed: luderitz
# City NOT found: khonuu
# City processed: takhtamygda
# City processed: viedma
# City processed: tual
# City processed: raga
# City processed: bilibino
# City processed: ponta do sol
# City processed: outjo
# City processed: hofn
# City processed: torbay
# City processed: teguldet
# City processed: paso de los toros
# City processed: rio grande
# City NOT found: nacunday
# City processed: puyang
# City processed: kenai
# City processed: santa maria del oro
# City processed: ojinaga
# City processed: tankhoy
# City processed: cody
# City processed: moose factory
# City processed: san cristobal
# City processed: thinadhoo
# City processed: hailey
# City processed: sao raimundo nonato
# City processed: marrakesh
# City processed: ilulissat
# City processed: villanueva
# City processed: chengde
# City processed: guerrero negro
# City processed: ponta delgada
# City processed: montoro
# City processed: le port
# City processed: whitley bay
# City processed: ramsgate
# City processed: alofi
# City processed: imbituba
# City processed: camabatela
# City processed: hurghada
# City NOT found: litoral del san juan
# City processed: otane
# City processed: tokur
# City processed: burla
# City processed: bathurst
# City processed: netrakona
# City processed: santa luzia
# City processed: caibarien
# City NOT found: chagda
# City processed: warwick
# City processed: smolensk
# City processed: ulladulla
# City processed: bela
# City processed: akyab
# City processed: vagur
# City processed: high level
# City processed: ranong
# City processed: nuuk
# City processed: aripuana
# City processed: kutum
# City processed: kalemie
# City processed: fairbanks
# City processed: acapulco
# City processed: lasa
# City processed: peleduy
# City processed: kaabong
# City processed: taltal
# City processed: rancho cucamonga
# City processed: paamiut
# City processed: grand-lahou
# City processed: turukhansk
# City NOT found: lolua
# City processed: codrington
# City processed: molchanovo
# City processed: andenes
# City processed: haren
# City processed: kango
# City processed: hualmay
# City processed: tazmalt
# City processed: chupa
# City processed: emerald
# City processed: palmer
# City processed: balkanabat
# City processed: pundaguitan
# City NOT found: nizhneyansk
# City processed: luxor
# City processed: tommot
# City processed: kaupanger
# City processed: belyy yar
# City processed: sadao
# City processed: krasnoyarka
# City processed: tiksi
# City processed: la macarena
# City processed: saint-pierre
# City processed: that phanom
# City processed: schitu
# City processed: padang
# City processed: filingue
# City processed: parrita
# City processed: tevaitoa
# City processed: balkhash
# City processed: curanilahue
# City processed: grand forks
# City processed: big spring
# City processed: fez
# City processed: chara
# City processed: saint-augustin
# City NOT found: bur gabo
# City processed: homer
# City processed: gijon
# City processed: zabid
# City processed: tsaratanana
# City processed: vila velha
# City processed: noci
# City processed: henties bay
# City processed: astana
# City processed: luan
# City processed: rocha
# City processed: hambantota
# City processed: broome
# City processed: bathsheba
# City processed: tocopilla
# City processed: kimbe
# City processed: maniitsoq
# City processed: buala
# City processed: rojhan
# City processed: oliveira dos brejinhos
# City processed: caracoli
# City processed: tabat
# City NOT found: bolungarvik
# City processed: shar
# City processed: manta
# City processed: chokwe
# City processed: bafoulabe
# City processed: katsuura
# City processed: umea
# City processed: serenje
# City processed: port arthur
# City processed: surgana
# City processed: maningrida
# City processed: sobolevo
# City processed: miri
# City processed: maine-soroa
# City processed: kampene
# City NOT found: grand river south east
# City processed: kalmunai
# City processed: nador
# City processed: sibolga
# City processed: kaeo
# City processed: kirensk
# City processed: boma
# City processed: kalakamati
# City NOT found: tunduru
# City processed: susaki
# City processed: makasar
# City NOT found: rungata
# City processed: semporna
# City processed: salinopolis
# City processed: dudinka
# City processed: fortuna
# City processed: portland
# City processed: bowen
# City processed: nara
# City processed: pyaozerskiy
# City processed: ushtobe
# City processed: kadhan
# City processed: joroan
# City processed: pacific grove
# City processed: badou
# City processed: sandpoint
# City processed: soure
# City processed: mamakan
# City processed: kaya
# City processed: manakara
# City processed: muzhi
# City processed: lorengau
# City processed: havelock
# City processed: zhigalovo
# City processed: kuloy
# City processed: vila franca do campo
# City processed: geraldton
# City processed: sheregesh
# City processed: encheng
# City processed: yar-sale
# City processed: ramanuj ganj
# City processed: hwange
# City processed: buluang
# City NOT found: samusu
# City processed: chandvad
# City processed: tabuk
# City processed: narsaq
# City processed: auki
# City processed: erenhot
# City processed: ketchikan
# City processed: morondava
# City processed: rajpipla
# City processed: selizharovo
# City processed: sur
# City processed: kazuno
# City processed: reconquista
# City processed: nemencine
# City processed: tomohon
# City processed: matara
# City processed: cagliari
# City processed: anadyr
# City NOT found: tsihombe
# City processed: pau
# City processed: harnosand
# City processed: santa vitoria do palmar
# City processed: pevek
# City processed: hamilton
# City processed: vao
# City processed: winnemucca
# City processed: rudnichnyy
# City processed: tuatapere
# City processed: ahipara
# City processed: cangzhou
# City processed: uniara
# City processed: kolokani
# City processed: kavieng
# City processed: tashara
# City processed: terrak
# City processed: makakilo city
# City processed: itarema
# City processed: palu
# City NOT found: anar darreh
# City processed: madimba
# City processed: banda aceh
# City processed: evensk
# City processed: kachiry
# City processed: miandrivazo
# City processed: mortka
# City processed: banff
# City processed: kysyl-syr
# City processed: sinnamary
# City processed: severo-kurilsk
# City processed: kemin
# City processed: kambove
# City processed: hsinchu
# City processed: okhotsk
# City processed: arlit
# City processed: luanda
# City processed: lae
# City processed: havoysund
# City processed: gizo
# City processed: waipawa
# City processed: kaseda
# City processed: chorozinho
# City processed: waynesville
# City processed: progreso
# City processed: japura
# City processed: assis
# City processed: vic
# City processed: marovoay
# City processed: kieta
# City processed: isla mujeres
# City processed: diego de almagro
# City processed: leningradskiy
# City processed: la ronge
# City processed: riyadh
# City processed: gibara
# City processed: teknaf
# City processed: oistins
# City processed: egvekinot
# City processed: manaure
# City processed: cotonou
# City processed: eydhafushi
# City processed: astoria
# City processed: cayenne
# City processed: new pitsligo
# City processed: xai-xai
# City processed: lavrentiya
# City processed: fallon
# City processed: zhanaozen
# City processed: hazorasp
# City processed: matay
# City processed: sandwick
# City processed: milkovo
# City processed: shuiji
# City processed: latung
# City processed: hede
# City processed: muravlenko
# City processed: maceio
# City processed: acultzingo
# City processed: conakry
# City processed: trang
# City processed: havre
# City NOT found: nguiu
# City processed: conil
# City NOT found: yian
# City processed: san rafael del sur
# City processed: salalah
# City processed: borogontsy
# City processed: wuxue
# City processed: sakaiminato
# City processed: novoagansk
# City processed: bafra
# City processed: hoa binh
# City processed: bahawalpur
# City processed: holme
# City NOT found: ambodifototra
# City processed: umm lajj
# City processed: cacu
# City processed: cortez
# City processed: icatu
# City processed: ixtapa
# City processed: sangar
# City processed: belmonte
# City processed: dzhebariki-khaya
# City processed: tukrah
# City processed: amapa
# City processed: ternate
# City processed: cairns
# City processed: roblin
# City processed: huarmey
# City processed: cooma
# City NOT found: marcona
# City processed: bonthe
# City processed: beipiao
# City processed: marana
# City processed: choszczno
# City processed: marsaxlokk
# City processed: coahuayana
# City processed: devonport
# City processed: saint michael
# City processed: saint-georges
# City processed: tomatlan
# City processed: ouargaye
# City processed: calvinia
# City processed: graham
# City processed: faya
# City processed: cururupu
# City processed: soltau
# City processed: zhigansk
# City processed: shimoda
# City processed: port moresby
# City NOT found: viligili
# City processed: aginskoye
# City processed: sal rei
# City processed: bukachacha
# City processed: kemijarvi
# City processed: muriwai beach
# City processed: elko
# City processed: san luis
# City processed: baruun-urt
# City processed: sao sebastiao
# City processed: sola
# City processed: swift current
# City processed: borba
# City processed: port hedland
# City processed: ambon
# City processed: xingtai
# City processed: lakes entrance
# City processed: tura
# City NOT found: baboua
# City processed: marathon
# City processed: goundam
# City processed: feijo
# City processed: pueblo
# City processed: putina
# City processed: channel-port aux basques
# City processed: hindoria
# City processed: benguela
# City processed: sabang

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
Weather_DF = pd.DataFrame({"City": foundCities,
                           "Temperature": temp,
                           "Humidity": humidity,
                           "Cloudiness": cloudiness,
                           "Windspeed":windSpeed,
                           "Latitude": lat,
                           "Longitude": lon,
                           "Date": date
                          })

# %%
#Windows desktop path
#Weather_DF.to_csv(r'/Users/matth/OneDrive/Desktop/GitClones/python-api-challenge/WeatherPy/weather.csv', index = False)
#Macbook path
Weather_DF.to_csv(r'/Users/md/Desktop/python-api-challenge/output_data/Cities.csv', index = False)
Weather_DF
# Out:
#                          City  Temperature  Humidity  Cloudiness  Windspeed  \
# 0                     mataura        39.00        83           0       3.00
# 1                        hilo        80.60        69          90       4.70
# 2                      albany        88.00        60          39       1.99
# 3                      bethel        78.01        69          75      11.41
# 4                        fare        80.80        77          99       5.23
# ..                        ...          ...       ...         ...        ...
# 597                    putina        51.10        41          92       8.23
# 598  channel-port aux basques        58.01        78          74      13.71
# 599                  hindoria        79.88        73         100      13.94
# 600                  benguela        71.26        80           0       3.96
# 601                    sabang        83.05        74          91       8.34
#
#      Latitude  Longitude        Date
# 0      -46.19     168.86  1592512095
# 1       19.73    -155.09  1592512095
# 2       42.60     -73.97  1592512096
# 3       41.37     -73.41  1592512096
# 4      -16.70    -151.02  1592511936
# ..        ...        ...         ...
# 597    -15.47     -69.43  1592512191
# 598     47.57     -59.14  1592512191
# 599     23.90      79.57  1592511914
# 600    -12.58      13.41  1592512191
# 601      5.89      95.32  1592512191
#
# [602 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
badHumidityDF = Weather_DF[(Weather_DF['Humidity'] >= 100)]
badHumidityDF
# Out:
#              City  Temperature  Humidity  Cloudiness  Windspeed  Latitude  \
# 44       koronowo        66.00       100          40       3.36     53.31
# 51         hasaki        64.00       100          75       4.70     35.73
# 70      newcastle        53.01       100          90       5.82    -32.93
# 80         lashio        70.02       100         100       1.54     22.93
# 102         airai        58.78       100          82       4.23     -8.93
# 122    dzerzhinsk        61.00       100           0       5.61     56.24
# 157      klaksvik        48.20       100         100       4.70     62.23
# 199      thompson        37.40       100          90      13.87     55.74
# 200     kabanjahe        77.00       100          40       4.70      3.10
# 204     kathmandu        69.80       100          75       3.29     27.72
# 209    launceston        42.01       100         100       8.05    -41.45
# 236          naze        78.80       100         100      11.41     28.37
# 305     ulladulla        44.01       100           1       6.15    -35.35
# 341         sadao        78.80       100          20       2.24      6.64
# 409          nara        64.99       100          75       8.05     34.69
# 439     ketchikan        57.20       100          90      23.04     55.34
# 490        kaseda        75.00       100         100      11.01     31.42
# 556         cooma        33.80       100           0      12.75    -36.23
# 572        soltau        61.00       100          75       4.70     52.98
# 588  port hedland        60.80       100          90       5.82    -20.32
#
#      Longitude        Date
# 44       17.94  1592512101
# 51      140.83  1592512102
# 70      151.78  1592511966
# 80       97.75  1592512107
# 102     125.41  1592512111
# 122      43.46  1592512114
# 157      -6.59  1592512121
# 199     -97.86  1592512127
# 200      98.49  1592512127
# 204      85.32  1592511969
# 209     147.17  1592512128
# 236     129.48  1592512132
# 305     150.47  1592512143
# 341     100.42  1592512150
# 409     135.80  1592512038
# 439    -131.65  1592512164
# 490     130.32  1592512174
# 556     149.13  1592512184
# 572       9.83  1592512186
# 588     118.57  1592512189

# %%
#  Get the indices of cities that have humidity over 100%.
badHumidityDF.index
# Out:
# Int64Index([ 44,  51,  70,  80, 102, 122, 157, 199, 200, 204, 209, 236, 305,
#             341, 409, 439, 490, 556, 572, 588],
#            dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data =

# %%
# Extract relevant fields from the data frame
City_Data = Weather_DF[["City","Latitude", "Temperature", "Humidity", "Cloudiness", "Windspeed", "Date"]]

# Export the City_Data into a csv
City_Data.to_csv(r'/Users/md/Desktop/python-api-challenge/output_data/City_Data.csv', index = False)
City_Data.head()
# Out:
#       City  Latitude  Temperature  Humidity  Cloudiness  Windspeed        Date
# 0  mataura    -46.19        39.00        83           0       3.00  1592512095
# 1     hilo     19.73        80.60        69          90       4.70  1592512095
# 2   albany     42.60        88.00        60          39       1.99  1592512096
# 3   bethel     41.37        78.01        69          75      11.41  1592512096
# 4     fare    -16.70        80.80        77          99       5.23  1592511936

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
endRunDate = City_Data["Date"].max()
runDate = datetime.utcfromtimestamp(endRunDate).strftime('%Y-%m-%d')
x = City_Data["Latitude"]
y = City_Data["Temperature"]
plt.scatter(x,y)
plt.grid()
plt.title(f"Latitude vs Temperature on {runDate}")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig(f'../output_data/Latitude vs Temperature on {runDate}.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#endDate = City_Data["Date"].max()
#x = City_Data["Latitude"]
h = City_Data["Humidity"]
plt.scatter(x,h)
plt.title(f"Latitude vs Humidity on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig(f'../output_data/Latitude vs Humidity on {runDate}.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
c = City_Data["Cloudiness"]
plt.scatter(x,c)
plt.title(f"Latitude vs Cloudiness on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig(f'../output_data/Latitude vs Cloudiness on {runDate}.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
ws = City_Data["Windspeed"]
plt.scatter(x,ws)
plt.title(f"Latitude vs Windspeed on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Windspeed (mph)")
plt.savefig(f'../output_data/Latitude vs Windspeed on {runDate}.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
