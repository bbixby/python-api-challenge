# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
#install from command line before opening jupyter notebook as 'pip install citipy'
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url for query with imperial units and city at the end
#url from https://openweathermap.org/appid
url = "http://api.openweathermap.org/data/2.5/weather?id=524901"
unit = "imperial"
query_url = f"{url}&appid={weather_api_key}&units={unit}&q="

# Lists for results
lat = []
lon = []
foundCities = []
temp = []
humidity = []
cloudiness = []
windSpeed = []
date = []

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windSpeed.append(response["wind"]["speed"])
        date.append(response["dt"])
        foundCities.append(city)
        print(f"City processed: {city}")
    except:
        print(f"City NOT found: {city}")
# Out:
# City processed: bredasdorp
# City processed: barrow
# City processed: punta arenas
# City processed: port elizabeth
# City processed: rikitea
# City processed: uvarovka
# City processed: fortuna
# City processed: sorland
# City processed: kodiak
# City processed: salinopolis
# City processed: ribeira grande
# City processed: port alfred
# City processed: bentiu
# City processed: san quintin
# City processed: umm lajj
# City processed: busselton
# City processed: yellowknife
# City processed: puerto ayora
# City processed: mataura
# City processed: kaitangata
# City processed: el dorado
# City processed: arraial do cabo
# City processed: bhum
# City processed: qaanaaq
# City processed: vaini
# City processed: vilcun
# City processed: bongandanga
# City processed: georgetown
# City processed: mabaruma
# City processed: saint-philippe
# City processed: lavrentiya
# City processed: butaritari
# City processed: margate
# City processed: port hawkesbury
# City processed: rocha
# City processed: torbay
# City processed: tuktoyaktuk
# City processed: jamestown
# City processed: cherskiy
# City processed: dwarka
# City processed: manavalakurichi
# City processed: luderitz
# City processed: vardo
# City processed: lask
# City processed: sergeyevka
# City processed: amlagora
# City processed: ushuaia
# City NOT found: mys shmidta
# City processed: oistins
# City processed: flin flon
# City processed: cape town
# City processed: faya
# City processed: atuona
# City processed: jimo
# City processed: saldanha
# City processed: taixing
# City processed: hithadhoo
# City processed: paragominas
# City processed: yatou
# City processed: severo-yeniseyskiy
# City processed: malindi
# City processed: bengkulu
# City processed: banepa
# City processed: rodniki
# City processed: hobart
# City processed: conceicao das alagoas
# City processed: tura
# City processed: hilo
# City processed: thompson
# City processed: wuda
# City processed: vodnyy
# City processed: hermanus
# City processed: saravan
# City processed: dikson
# City processed: islampur
# City processed: ilulissat
# City NOT found: tsihombe
# City processed: zhangzhou
# City NOT found: barentsburg
# City processed: vila franca do campo
# City processed: provideniya
# City processed: faanui
# City processed: najran
# City processed: bambous virieux
# City processed: olafsvik
# City NOT found: sentyabrskiy
# City processed: san patricio
# City processed: herat
# City processed: klaksvik
# City processed: comodoro rivadavia
# City processed: cockburn town
# City processed: tuatapere
# City processed: abu samrah
# City processed: namtsy
# City NOT found: taolanaro
# City processed: oksfjord
# City processed: mackay
# City processed: sept-iles
# City processed: khatanga
# City processed: formosa do rio preto
# City processed: husavik
# City processed: port macquarie
# City NOT found: belushya guba
# City processed: ust-nera
# City processed: ahipara
# City processed: khandyga
# City processed: lamu
# City processed: talas
# City processed: pyapon
# City processed: mount gambier
# City NOT found: grand river south east
# City processed: east london
# City processed: kodinsk
# City processed: chokurdakh
# City processed: kapaa
# City processed: ostrovnoy
# City processed: avarua
# City processed: la reforma
# City processed: socorro
# City processed: lebu
# City processed: bara
# City processed: mahebourg
# City processed: paamiut
# City processed: opuwo
# City processed: krasnoselkup
# City processed: yulara
# City processed: saint-francois
# City processed: cayenne
# City processed: labuhan
# City processed: upernavik
# City processed: nishihara
# City processed: ati
# City processed: taoudenni
# City processed: alta floresta
# City processed: starogard gdanski
# City processed: emba
# City processed: recco
# City processed: zhicheng
# City processed: kaoma
# City processed: calarasi
# City processed: alyangula
# City processed: saint george
# City processed: ariquemes
# City processed: arman
# City processed: jumla
# City processed: balabac
# City processed: norman wells
# City processed: mar del plata
# City NOT found: palabuhanratu
# City processed: nanortalik
# City processed: carnarvon
# City processed: geraldton
# City NOT found: tsienyane
# City processed: nikolskoye
# City NOT found: borama
# City processed: churapcha
# City processed: moussoro
# City processed: taree
# City processed: bilma
# City processed: buin
# City processed: baltay
# City NOT found: kazalinsk
# City processed: kruisfontein
# City processed: coihaique
# City processed: belaya gora
# City processed: yeniseysk
# City processed: ossora
# City processed: castro
# City processed: walvis bay
# City processed: hibbing
# City processed: askiz
# City processed: warrensburg
# City processed: bowen
# City processed: saint-pierre
# City processed: cabo san lucas
# City processed: canakkale
# City processed: abu zabad
# City processed: rongcheng
# City processed: iqaluit
# City processed: machali
# City processed: sinnamary
# City processed: ambilobe
# City processed: touros
# City processed: albany
# City processed: elizabeth city
# City processed: leshukonskoye
# City processed: kavieng
# City processed: te anau
# City NOT found: illoqqortoormiut
# City NOT found: port-de-paix
# City processed: bluff
# City processed: sao filipe
# City processed: launceston
# City processed: cidreira
# City processed: praia da vitoria
# City processed: saint anthony
# City processed: kenai
# City processed: eyl
# City processed: tumaco
# City processed: hualmay
# City processed: alofi
# City processed: paravola
# City processed: clyde river
# City NOT found: saleaula
# City processed: totness
# City processed: kununurra
# City processed: half moon bay
# City processed: uruzgan
# City processed: pacific grove
# City processed: hofn
# City processed: puerto escondido
# City processed: menongue
# City processed: fazilka
# City NOT found: qabis
# City processed: atambua
# City processed: rock sound
# City processed: cukai
# City NOT found: maloshuyka
# City processed: riyadh
# City processed: qeshm
# City processed: lompoc
# City processed: oriximina
# City processed: xining
# City processed: awbari
# City processed: port hedland
# City processed: ponta do sol
# City processed: gigmoto
# City processed: glendive
# City processed: new norfolk
# City processed: celestun
# City processed: korgen
# City processed: maple creek
# City processed: dunedin
# City processed: porrentruy
# City processed: kabalo
# City processed: padang
# City processed: karla
# City processed: sambava
# City processed: kahului
# City processed: aykhal
# City processed: severnyy-kospashskiy
# City processed: rapid valley
# City NOT found: bolungarvik
# City processed: yar-sale
# City processed: omsukchan
# City processed: katsuura
# City processed: saint-augustin
# City processed: carutapera
# City processed: manali
# City processed: auki
# City processed: tarko-sale
# City processed: uarini
# City processed: malinovskiy
# City processed: wanning
# City processed: severo-kurilsk
# City processed: san cristobal
# City processed: ocos
# City processed: sur
# City processed: locri
# City processed: beloha
# City processed: sitka
# City NOT found: amderma
# City processed: puerto madryn
# City processed: goiatuba
# City processed: mayo
# City NOT found: ust-kamchatsk
# City processed: honiara
# City processed: seybaplaya
# City NOT found: vaitupu
# City processed: sola
# City processed: shitanjing
# City processed: norrtalje
# City processed: kybartai
# City processed: oussouye
# City processed: grandola
# City processed: sioux lookout
# City processed: kautokeino
# City processed: talnakh
# City processed: port blair
# City processed: tiksi
# City processed: zhoucheng
# City processed: cuiluan
# City processed: revda
# City processed: vila
# City processed: farmington
# City processed: puerto colombia
# City processed: panzhihua
# City processed: esperance
# City NOT found: wahran
# City processed: sistranda
# City processed: lyaskelya
# City processed: zhezkazgan
# City processed: makakilo city
# City processed: talara
# City processed: leningradskiy
# City processed: longyearbyen
# City processed: byron bay
# City processed: markova
# City processed: el playon
# City processed: kilindoni
# City processed: amahai
# City NOT found: umzimvubu
# City processed: salta
# City processed: nurota
# City NOT found: bargal
# City processed: roald
# City processed: muisne
# City processed: yakeshi
# City processed: hasaki
# City processed: lere
# City processed: cabedelo
# City processed: palmer
# City processed: salihorsk
# City processed: grindavik
# City processed: port lincoln
# City processed: shelburne
# City processed: hami
# City NOT found: tabiauea
# City processed: mizque
# City processed: killybegs
# City processed: qasigiannguit
# City processed: ponta delgada
# City processed: guerrero negro
# City processed: hoyanger
# City NOT found: labutta
# City processed: north bend
# City processed: huarmey
# City processed: marshfield
# City processed: rawson
# City processed: brigantine
# City processed: america dourada
# City processed: victoria
# City processed: iranshahr
# City processed: synya
# City NOT found: louisbourg
# City processed: brae
# City processed: tasiilaq
# City processed: peniche
# City processed: camacha
# City processed: petropavlovsk-kamchatskiy
# City processed: wilmington
# City processed: diamantino
# City processed: stony mountain
# City NOT found: grimari
# City processed: sosnovo-ozerskoye
# City processed: lazarev
# City processed: souillac
# City processed: kieta
# City processed: vao
# City processed: kandrian
# City processed: madimba
# City processed: high level
# City processed: mnogovershinnyy
# City processed: safaga
# City processed: rincon
# City processed: paso de los toros
# City processed: bethel
# City processed: ishigaki
# City processed: hambantota
# City processed: magadan
# City processed: anjiang
# City processed: ancud
# City processed: ixtapa
# City processed: panaba
# City processed: kloulklubed
# City processed: acapulco
# City processed: dakar
# City processed: magalia
# City processed: manzhouli
# City processed: lorengau
# City processed: guerrero
# City processed: chapais
# City processed: imeni poliny osipenko
# City processed: kyaukse
# City NOT found: kamenskoye
# City processed: fukue
# City processed: antofagasta
# City processed: grande prairie
# City processed: oktyabrskiy
# City processed: sakakah
# City processed: mogok
# City processed: portland
# City processed: debre birhan
# City NOT found: burica
# City processed: komsomolskiy
# City processed: arroyo
# City processed: black river
# City processed: nadym
# City processed: caravelas
# City processed: aklavik
# City processed: kamarion
# City processed: cairns
# City processed: santa lucia
# City processed: oranjemund
# City processed: potsdam
# City processed: iringa
# City processed: quimper
# City processed: bhanjanagar
# City processed: meulaboh
# City processed: belomorsk
# City NOT found: sorvag
# City processed: sabha
# City processed: thohoyandou
# City processed: khartoum
# City NOT found: tarudant
# City processed: kaeo
# City processed: matagami
# City processed: biak
# City processed: sandy bay
# City processed: ust-barguzin
# City processed: aksarka
# City processed: narsaq
# City processed: isangel
# City processed: fort nelson
# City processed: langxiang
# City processed: novyy urengoy
# City processed: imeni babushkina
# City processed: rorvik
# City processed: aswan
# City processed: pelym
# City processed: dingle
# City processed: odweyne
# City NOT found: warqla
# City processed: klyuchi
# City processed: gornopravdinsk
# City processed: lazaro cardenas
# City processed: mount isa
# City NOT found: mouzakion
# City NOT found: nizhneyansk
# City processed: emerald
# City processed: berdigestyakh
# City processed: pitsunda
# City processed: tilichiki
# City processed: taltal
# City processed: murray bridge
# City NOT found: meyungs
# City processed: fort saint james
# City processed: saurimo
# City NOT found: samusu
# City NOT found: yanan
# City processed: greenville
# City processed: miracema do tocantins
# City processed: constitucion
# City processed: seoul
# City processed: vaitape
# City processed: saskylakh
# City processed: hay river
# City processed: galle
# City processed: hailar
# City processed: nabire
# City NOT found: one hundred mile house
# City processed: anantapur
# City processed: dzhebariki-khaya
# City processed: mezhdurechenskiy
# City processed: henties bay
# City processed: young
# City processed: panama city
# City processed: mayahi
# City processed: nhulunbuy
# City processed: huntingdon
# City processed: amuntai
# City processed: finnsnes
# City processed: begun
# City processed: vestmanna
# City processed: toora-khem
# City processed: lodja
# City processed: venancio aires
# City processed: shingu
# City processed: sao miguel do araguaia
# City processed: iwaki
# City processed: palaia fokaia
# City processed: pokrovsk
# City processed: zhengjiatun
# City processed: laguna
# City processed: stanghelle
# City processed: ulladulla
# City processed: nogliki
# City processed: panjakent
# City processed: limuru
# City processed: shellbrook
# City processed: edd
# City processed: lata
# City processed: manuk mangkaw
# City processed: zheleznodorozhnyy
# City processed: yanam
# City processed: nome
# City processed: sabratah
# City processed: rio cuarto
# City processed: griffith
# City processed: heihe
# City processed: avera
# City processed: trojes
# City processed: calabozo
# City processed: illela
# City processed: yamada
# City processed: fairbanks
# City processed: mchinji
# City processed: sindi
# City processed: pingliang
# City processed: ilo
# City NOT found: rawannawi
# City processed: carndonagh
# City processed: vostok
# City processed: la orilla
# City NOT found: beruni
# City processed: santa maria
# City processed: rangia
# City processed: mancio lima
# City processed: ojinaga
# City processed: gambo
# City processed: burla
# City processed: maracas
# City processed: cooma
# City processed: cervo
# City processed: sault sainte marie
# City processed: kingsport
# City processed: deputatskiy
# City processed: douglasville
# City processed: birin
# City processed: yagoua
# City processed: diego de almagro
# City processed: codrington
# City processed: kyra
# City NOT found: samalaeulu
# City processed: mazagao
# City processed: hobyo
# City processed: pontes e lacerda
# City processed: pervomayskiy
# City processed: morgaushi
# City processed: luan
# City processed: yinchuan
# City processed: benemerito de las americas
# City processed: vila velha
# City processed: huilong
# City processed: yumen
# City processed: zhatay
# City processed: kysyl-syr
# City processed: shaping
# City NOT found: cam pha
# City processed: pevek
# City processed: bud
# City processed: luz
# City processed: san andres
# City processed: huanren
# City processed: krasnyy chikoy
# City processed: kindersley
# City processed: praya
# City processed: thinadhoo
# City processed: sao joao da barra
# City processed: jasper
# City processed: tomatlan
# City processed: tokmak
# City processed: gidole
# City processed: magdagachi
# City processed: abay
# City processed: astara
# City processed: kashi
# City processed: lagoa
# City processed: parana
# City processed: aksu
# City NOT found: khonuu
# City processed: verkh-usugli
# City processed: bilibino
# City processed: sigli
# City processed: cururupu
# City processed: sulmona
# City processed: tumpat
# City processed: ludvika
# City processed: quatre cocos
# City processed: morehead
# City processed: aras
# City processed: ewa beach
# City processed: nuuk
# City processed: robore
# City processed: redlands
# City processed: guane
# City processed: saint-tite
# City processed: kirovskiy
# City processed: xichang
# City processed: chiredzi
# City processed: olbia
# City processed: malangwa
# City NOT found: bobonong
# City processed: buala
# City processed: khor
# City processed: suez
# City NOT found: longlac
# City processed: borba
# City processed: rio grande
# City processed: stowe
# City processed: wad rawah
# City processed: sobolevo
# City processed: nizwa
# City processed: eganville
# City NOT found: mocambique
# City processed: lokosovo
# City processed: tevriz
# City processed: suntar
# City processed: ornskoldsvik
# City processed: tulum
# City processed: kandiaro
# City processed: tianpeng
# City processed: mayumba
# City processed: takoradi
# City processed: songkhla
# City processed: fare
# City processed: tarata
# City processed: kirakira
# City processed: garissa
# City processed: pangnirtung
# City processed: san vicente
# City processed: pore

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
Weather_DF = pd.DataFrame({"City": foundCities,
                           "Temperature": temp,
                           "Humidity": humidity,
                           "Cloudiness": cloudiness,
                           "Windspeed":windSpeed,
                           "Latitude": lat,
                           "Longitude": lon,
                           "Date": date
                          })

# %%
#Windows desktop path
Weather_DF.to_csv(r'/Users/matth/OneDrive/Desktop/GitClones/python-api-challenge/output_data/Cities.csv', index = False)
#Macbook path
#Weather_DF.to_csv(r'/Users/md/Desktop/python-api-challenge/output_data/Cities.csv', index = False)
Weather_DF
# Out:
#                City  Temperature  Humidity  Cloudiness  Windspeed  Latitude  \
# 0        bredasdorp        69.80        52           0       2.53    -34.53
# 1            barrow        33.80        87          90      13.87     71.29
# 2      punta arenas        35.60        93          75       9.17    -53.15
# 3    port elizabeth        75.20        29           0       3.36    -33.92
# 4           rikitea        73.24        89         100      15.08    -23.12
# ..              ...          ...       ...         ...        ...       ...
# 561        kirakira        79.07        82         100       7.52    -10.45
# 562         garissa        84.31        46          38      22.59     -0.45
# 563     pangnirtung        37.40        93          75       5.82     66.15
# 564     san vicente        75.38        56          91       8.30    -26.62
# 565            pore        80.89        70          48       8.19      5.73
#
#      Longitude        Date
# 0        20.04  1592581173
# 1      -156.79  1592581173
# 2       -70.92  1592581173
# 3        25.57  1592581068
# 4      -134.97  1592581173
# ..         ...         ...
# 561     161.92  1592581234
# 562      39.64  1592581234
# 563     -65.71  1592581086
# 564     -54.13  1592581234
# 565     -71.99  1592581234
#
# [566 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
badHumidityDF = Weather_DF[(Weather_DF['Humidity'] > 100)]
badHumidityDF
# Out:
# Empty DataFrame
# Columns: [City, Temperature, Humidity, Cloudiness, Windspeed, Latitude, Longitude, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
badHumidityDF.index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data =

# %%
# Extract relevant fields from the data frame
City_Data = Weather_DF[["City","Latitude", "Temperature", "Humidity", "Cloudiness", "Windspeed", "Date"]]

# Export the City_Data into a csv
#Windows path
City_Data.to_csv(r'/Users/matth/OneDrive/Desktop/GitClones/python-api-challenge/output_data/City_Data.csv', index = False)
#Macbook path
#City_Data.to_csv(r'/Users/md/Desktop/python-api-challenge/output_data/City_Data.csv', index = False)
City_Data.head()
# Out:
#              City  Latitude  Temperature  Humidity  Cloudiness  Windspeed  \
# 0      bredasdorp    -34.53        69.80        52           0       2.53
# 1          barrow     71.29        33.80        87          90      13.87
# 2    punta arenas    -53.15        35.60        93          75       9.17
# 3  port elizabeth    -33.92        75.20        29           0       3.36
# 4         rikitea    -23.12        73.24        89         100      15.08
#
#          Date
# 0  1592581173
# 1  1592581173
# 2  1592581173
# 3  1592581068
# 4  1592581173

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#format the max date in the dataset as "runDate" for graph titles
endRunDate = City_Data["Date"].max()
runDate = datetime.utcfromtimestamp(endRunDate).strftime('%Y-%m-%d')

#set data to plot
x = City_Data["Latitude"]
y = City_Data["Temperature"]
plt.scatter(x,y)
#add gridlines
plt.grid()
#add titles and axis labels
plt.title(f"Latitude vs Temperature on {runDate}")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
#export as png
plt.savefig(f'../output_data/Latitude vs Temperature on {runDate}.png')
#display plot!
plt.show()

# %% [markdown]
# ### Latitude vs Temperature Scatter Plot Insights
#
# The scatter plot maps cities' temperature against their latitude.  Cities selected randomly.
# The arc of the scatter plot shows temperature increasing near the equator (Latitude 0) and dropping off further away. Given the run date of June 2020, the plot also skews higher temperatures to the right of the equator due to summer in the northern hemisphere.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#set data to plot; retain Latitude from previous plot as "x"
h = City_Data["Humidity"]
plt.scatter(x,h)
plt.title(f"Latitude vs Humidity on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig(f'../output_data/Latitude vs Humidity on {runDate}.png')
plt.show()

# %% [markdown]
# ### Latitude vs Humidity Scatter Plot Insights
#
# The scatter plot maps cities' humidity against their latitude.  Cities selected randomly.
#
# The result reveals no particular correlation between humidity and latitude.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
c = City_Data["Cloudiness"]
plt.scatter(x,c)
plt.title(f"Latitude vs Cloudiness on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig(f'../output_data/Latitude vs Cloudiness on {runDate}.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Latitude vs Cloudiness Scatter Plot Insights
#
# The scatter plot maps cities' cloudiness percent against their latitude.  Cities selected randomly.
#
# The result reveals no particular correlation between cloudiness and latitude. There may however be a slight bias towards round cloudiness percentages, given the groupings near each 10s line (ex: 40% cloudiness).

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
ws = City_Data["Windspeed"]
plt.scatter(x,ws)
plt.title(f"Latitude vs Windspeed on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Windspeed (mph)")
plt.savefig(f'../output_data/Latitude vs Windspeed on {runDate}.png')
plt.show()

# %% [markdown]
# ### Latitude vs Wind Speed Scatter Plot Insights
#
# The scatter plot maps cities' wind speed against their latitude.  Cities selected randomly.
#
# The result reveals no particular correlation between wind speed and latitude.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

#function to call is "linearRegression"
#variables are
# x_values: first set of data
# y_values: second set of data
# regEQplotX: where the linear regression equasion appears on the plot x line
# regEQplotY: where the linear regression equasion appears on the plot y line
# y_label: the y axis label of the plot (x label is always Latitude)

def linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f'The r-square is {rvalue}')
    print(line_eq)
    plt.annotate(line_eq,(regEQplotX,regEQplotY),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{y_label}')
    plt.grid()

# %%
# Create Northern and Southern Hemisphere DataFrames
#pull loc above and below the equator; note any cities directly on the equator (i.e. latitude = 0) are excluded
Northern_DF = Weather_DF.loc[Weather_DF["Latitude"] > 0]
Southern_DF = Weather_DF.loc[Weather_DF["Latitude"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set the data sets to compare
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Temperature"]
#tweak where the equation appears on the plot
regEQplotX = 0
regEQplotY = 40
#label the y axis
y_label = "Temperature (F)"
#give the title
plt.title(f'Northern Hemisphere Latitude vs Temp on {runDate}')
#run the function with all 5 variables
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
#save as a png to the neighboring output_data folder
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Temp on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.7169968211038665
# y = -0.58x + 94.04

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Temperature"]
regEQplotX = -25
regEQplotY = 40
y_label = "Temperature (F)"
plt.title(f'Southern Hemisphere Latitude vs Temp on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Temp on {runDate}.png')
plt.show()
# Out:
# The r-square is 0.8175825713670323
# y = 0.81x + 85.79

# %% [markdown]
# ### North/South Latitude vs TEMPERATURE Linear Regression Insights
#
# The scatter plot maps Northern and Southern cities' temperature against their latitude.  Cities selected randomly.
#
# The result reveals

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Humidity"]
regEQplotX = 45
regEQplotY = 15
y_label = "Humidity (%)"
plt.title(f'Northern Hemisphere Latitude vs Humidity on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Humidity on {runDate}.png')
plt.show()
# Out:
# The r-square is 0.009042292725634048
# y = 0.01x + 63.96

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Humidity"]
regEQplotX = -55
regEQplotY = 35
y_label = "Humidity (%)"
plt.title(f'Southern Hemisphere Latitude vs Humidity on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Humidity on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.05996145263465682
# y = -0.1x + 66.42

# %% [markdown]
# ### North/South Latitude vs HUMIDITY Linear Regression Insights
#
# The scatter plot maps Northern and Southern cities' humidity against their latitude.  Cities selected randomly.
#
# The result reveals

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Cloudiness"]
regEQplotX = 0
regEQplotY = 25
y_label = "Cloudiness (%)"
plt.title(f'Northern Hemisphere Latitude vs Cloudiness on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Cloudiness on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.04984162639302365
# y = -0.09x + 54.4

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Cloudiness"]
regEQplotX = -55
regEQplotY = 60
y_label = "Cloudiness (%)"
plt.title(f'Southern Hemisphere Latitude vs Cloudiness on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Cloudiness on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.1472638229751756
# y = -0.39x + 37.53

# %% [markdown]
# ### North/South Latitude vs CLOUDINESS Linear Regression Insights
#
# The scatter plot maps Northern and Southern cities' cloudiness against their latitude.  Cities selected randomly.
#
# The result reveals

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Windspeed"]
regEQplotX = 35
regEQplotY = 25
y_label = "Wind Speed (MPH)"
plt.title(f'Northern Hemisphere Latitude vs Wind Speed on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Wind Speed on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.024118873236452055
# y = -0.01x + 8.17

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Windspeed"]
regEQplotX = -50
regEQplotY = 25
y_label = "Wind Speed (MPH)"
plt.title(f'Southern Hemisphere Latitude vs Wind Speed on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Wind Speed on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.052551353048673505
# y = -0.02x + 8.24

# %% [markdown]
# ### North/South Latitude vs WIND SPEED Linear Regression Insights
#
# The scatter plot maps Northern and Southern cities' wind speed against their latitude.  Cities selected randomly.
#
# The result reveals
