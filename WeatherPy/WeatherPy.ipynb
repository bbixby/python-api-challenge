# %% [markdown]
# # WeatherPy
# ----
#
# #### Random City Generator and Weather Analysis by Latitudes

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
#install from command line before opening jupyter notebook as 'pip install citipy'
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url for query with imperial units and city at the end
#url from https://openweathermap.org/appid
url = "http://api.openweathermap.org/data/2.5/weather?id=524901"
unit = "imperial"
query_url = f"{url}&appid={weather_api_key}&units={unit}&q="

# Lists for results
lat = []
lon = []
foundCities = []
temp = []
humidity = []
cloudiness = []
windSpeed = []
date = []
country = []

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windSpeed.append(response["wind"]["speed"])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        foundCities.append(city)
        print(f"City processed: {city}")
    except:
        print(f"City NOT found: {city}")
# Out:
# City processed: ushuaia
# City processed: butaritari
# City NOT found: taolanaro
# City processed: mataura
# City processed: tsabong
# City processed: qaanaaq
# City processed: avarua
# City processed: tuktoyaktuk
# City processed: punta arenas
# City processed: barrow
# City processed: yagodnoye
# City processed: cape town
# City processed: faya
# City NOT found: saleaula
# City processed: hobart
# City processed: salinas
# City processed: sohag
# City processed: rikitea
# City processed: bairnsdale
# City NOT found: tsihombe
# City processed: te anau
# City processed: hattiesburg
# City processed: lorengau
# City processed: tiarei
# City processed: airai
# City processed: jamestown
# City processed: bagh
# City processed: moyale
# City processed: san quintin
# City NOT found: bolungarvik
# City processed: hilo
# City processed: san gabriel casa blanca
# City NOT found: barentsburg
# City processed: sitka
# City processed: port alfred
# City processed: new norfolk
# City processed: port elizabeth
# City processed: talnakh
# City processed: arraial do cabo
# City processed: castro
# City processed: kununurra
# City processed: vestmannaeyjar
# City processed: yulara
# City processed: blackwater
# City processed: esperance
# City processed: caborca
# City processed: baykit
# City processed: prata
# City NOT found: nizhneyansk
# City NOT found: illoqqortoormiut
# City processed: port augusta
# City processed: lompoc
# City NOT found: sentyabrskiy
# City processed: kimbe
# City processed: east london
# City processed: provideniya
# City processed: puerto ayora
# City processed: nizhniy kuranakh
# City processed: tasiilaq
# City processed: pevek
# City processed: albany
# City processed: coihaique
# City NOT found: tasbuget
# City processed: oranjestad
# City processed: sola
# City processed: yellowknife
# City processed: richards bay
# City processed: veraval
# City processed: belyy yar
# City processed: xuanzhou
# City processed: oranjemund
# City processed: kavieng
# City processed: batticaloa
# City processed: chumikan
# City processed: hermanus
# City processed: vaini
# City processed: nemuro
# City processed: carnarvon
# City processed: belaya gora
# City processed: port lincoln
# City processed: khatanga
# City NOT found: sumbawa
# City processed: laguna
# City processed: jalu
# City NOT found: amderma
# City processed: huayucachi
# City processed: kaduy
# City processed: cherskiy
# City processed: kodiak
# City processed: sao joao da barra
# City processed: chuy
# City processed: kaitangata
# City processed: san juan de uraba
# City processed: ikot ekpene
# City processed: zhangjiakou
# City processed: victoria
# City processed: kaeo
# City processed: pangnirtung
# City processed: san policarpo
# City NOT found: samusu
# City processed: vila franca do campo
# City processed: sierra vista
# City processed: svetlaya
# City processed: busselton
# City processed: dryden
# City processed: kapaa
# City processed: cidreira
# City processed: dikson
# City processed: shingu
# City processed: sinnamary
# City processed: todos santos
# City NOT found: karamea
# City processed: nanortalik
# City processed: thompson
# City processed: bredasdorp
# City processed: san rafael
# City processed: kirakira
# City processed: shestakovo
# City processed: blonie
# City processed: nuuk
# City processed: oktyabrsk
# City processed: kailua
# City processed: lokosovo
# City processed: tiksi
# City processed: moissala
# City processed: jidong
# City processed: ilulissat
# City processed: talcahuano
# City processed: kabwe
# City processed: georgetown
# City processed: soligalich
# City processed: dingle
# City processed: fort-shevchenko
# City processed: polyarnyy
# City processed: padang
# City processed: boa vista
# City processed: sidi ali
# City NOT found: belushya guba
# City processed: cihuatlan
# City processed: prince rupert
# City processed: nouakchott
# City processed: bluff
# City processed: nikolskoye
# City processed: atuona
# City processed: upernavik
# City processed: kazerun
# City NOT found: lolua
# City processed: faanui
# City processed: rocha
# City processed: hambantota
# City processed: alice
# City processed: saskylakh
# City processed: mount isa
# City processed: pimentel
# City processed: bengkulu
# City processed: ponferrada
# City processed: toora-khem
# City processed: lebu
# City processed: bethel
# City processed: mehamn
# City processed: porto novo
# City processed: ahipara
# City processed: multai
# City processed: boca do acre
# City processed: viisoara
# City processed: zabid
# City processed: gorontalo
# City processed: guerrero negro
# City processed: pinega
# City processed: evensk
# City processed: westport
# City processed: opuwo
# City processed: ndele
# City processed: catabola
# City processed: joshimath
# City processed: ketchikan
# City processed: estevan
# City processed: codrington
# City processed: paamiut
# City processed: san andres
# City processed: rapid valley
# City NOT found: grand river south east
# City processed: tatawin
# City processed: noumea
# City processed: torbay
# City processed: biak
# City processed: blagoyevo
# City processed: ha tinh
# City processed: hervey bay
# City processed: san patricio
# City processed: komsomolskiy
# City processed: banepa
# City processed: port-gentil
# City processed: haines junction
# City processed: beni
# City processed: saint-augustin
# City processed: chipinge
# City processed: maningrida
# City processed: saint-philippe
# City processed: turukhansk
# City processed: victoriaville
# City processed: oktyabrskoye
# City processed: teya
# City processed: bubaque
# City processed: vostok
# City processed: abu samrah
# City processed: dalvik
# City processed: clyde river
# City processed: senanga
# City processed: yumen
# City processed: simao
# City processed: mahebourg
# City processed: banganapalle
# City processed: el jicaro
# City processed: neiafu
# City processed: mweka
# City processed: vilhena
# City processed: quelimane
# City processed: lac du bonnet
# City processed: monrovia
# City processed: jaca
# City processed: mount gambier
# City processed: ostrovnoy
# City processed: asau
# City processed: santa marta
# City processed: kingaroy
# City processed: saint-pierre
# City processed: lichtenfels
# City processed: ribeira grande
# City processed: manicore
# City processed: sao filipe
# City processed: yarmouth
# City processed: suraia
# City processed: harrismith
# City processed: sao joao do piaui
# City processed: miri
# City processed: oeiras do para
# City NOT found: katha
# City processed: kavaratti
# City processed: zaysan
# City processed: lasa
# City processed: necochea
# City processed: ostersund
# City processed: el alto
# City processed: half moon bay
# City NOT found: bargal
# City processed: colares
# City processed: fare
# City processed: liberal
# City processed: sao mateus do sul
# City NOT found: guajara-mirim
# City processed: constitucion
# City processed: aswan
# City processed: birao
# City processed: saint-ambroise
# City processed: lafayette
# City processed: iracoubo
# City processed: gedera
# City processed: mayumba
# City processed: bonthe
# City processed: cabo san lucas
# City NOT found: palabuhanratu
# City processed: kamenka
# City processed: ponta do sol
# City processed: kahului
# City processed: pelym
# City processed: kruisfontein
# City processed: qaqortoq
# City processed: kabinda
# City processed: puerto rico
# City processed: baoding
# City processed: ramsar
# City processed: severo-kurilsk
# City processed: bereda
# City processed: barao de melgaco
# City processed: sillanwali
# City processed: lagoa
# City processed: chumphon
# City NOT found: attawapiskat
# City processed: odweyne
# City processed: hobyo
# City processed: kiunga
# City processed: fort nelson
# City processed: rio gallegos
# City processed: mar del plata
# City processed: roma
# City processed: bandarbeyla
# City processed: fortuna
# City processed: pokhara
# City processed: baruun-urt
# City processed: harrison
# City processed: cap malheureux
# City processed: souillac
# City processed: severnyy
# City NOT found: tawkar
# City NOT found: rungata
# City processed: mingrelskaya
# City processed: boende
# City processed: chicama
# City processed: deputatskiy
# City processed: abha
# City NOT found: kerteh
# City processed: gornyy
# City processed: sampang
# City processed: siquijor
# City processed: dongsheng
# City processed: vila do maio
# City processed: lata
# City processed: guanaja
# City processed: olbia
# City processed: port hardy
# City processed: kulhudhuffushi
# City processed: flin flon
# City processed: aklavik
# City processed: agua branca
# City processed: saint-andre-les-vergers
# City processed: coahuayana
# City processed: roquetas de mar
# City processed: svetlogorsk
# City processed: babocsa
# City processed: leh
# City processed: buala
# City processed: mareeba
# City processed: pombia
# City NOT found: umzimvubu
# City processed: hokitika
# City processed: sabang
# City processed: margate
# City processed: hasaki
# City processed: ambikapur
# City processed: korla
# City processed: la libertad
# City processed: quebo
# City processed: mandalgovi
# City processed: adrar
# City processed: newport
# City processed: portland
# City processed: okhotsk
# City processed: lavrentiya
# City processed: narsaq
# City processed: luau
# City processed: kalmunai
# City processed: port macquarie
# City processed: atambua
# City processed: eureka
# City processed: turbat
# City processed: florianopolis
# City processed: canandaigua
# City processed: chokurdakh
# City processed: ko samui
# City processed: acarau
# City processed: savannah bight
# City processed: lethem
# City processed: nelson bay
# City processed: lillehammer
# City processed: san pedro
# City processed: xuanhua
# City processed: yerbogachen
# City NOT found: mys shmidta
# City processed: madimba
# City NOT found: karauzyak
# City processed: chebarkul
# City processed: puerto escondido
# City processed: port hedland
# City processed: klaksvik
# City processed: kungurtug
# City processed: hofn
# City processed: marystown
# City processed: saint anthony
# City processed: chilliwack
# City processed: fern creek
# City processed: fatsa
# City processed: isangel
# City processed: sorland
# City processed: high level
# City processed: tahoua
# City processed: hami
# City processed: jadu
# City processed: flinders
# City processed: carauari
# City NOT found: dianopolis
# City processed: abu dhabi
# City processed: hvolsvollur
# City processed: marienburg
# City processed: bintulu
# City processed: dubti
# City processed: juan lacaze
# City processed: julio de castilhos
# City processed: grand forks
# City processed: colesberg
# City processed: lempaala
# City processed: grover beach
# City processed: fairbanks
# City processed: roald
# City processed: springbok
# City processed: zhigansk
# City processed: tuatapere
# City processed: luderitz
# City NOT found: vaitupu
# City processed: acajutla
# City processed: iqaluit
# City processed: mayya
# City processed: lewiston
# City processed: rawlins
# City processed: touros
# City processed: thinadhoo
# City processed: sebrovo
# City processed: bathsheba
# City processed: marzuq
# City processed: puerto carreno
# City processed: gazimurskiy zavod
# City processed: tutoia
# City processed: leningradskiy
# City processed: arklow
# City processed: los llanos de aridane
# City processed: usinsk
# City processed: enid
# City processed: boden
# City NOT found: mullaitivu
# City processed: campeche
# City processed: zambezi
# City processed: goderich
# City processed: panaba
# City processed: balsas
# City processed: manokwari
# City NOT found: meyungs
# City processed: eyl
# City processed: rockhampton
# City processed: pathein
# City processed: the valley
# City processed: ankazoabo
# City processed: saravan
# City processed: katsuura
# City processed: nove mesto na morave
# City processed: srednekolymsk
# City processed: tiznit
# City processed: whitehorse
# City processed: nome
# City processed: bara
# City NOT found: macaboboni
# City processed: homer
# City processed: fallon
# City processed: skjervoy
# City processed: ossora
# City processed: phan thiet
# City processed: bone
# City processed: dalby
# City processed: jumla
# City processed: nurota
# City processed: ancud
# City processed: soledade
# City processed: rawson
# City processed: takestan
# City processed: taltal
# City processed: atasu
# City processed: ystad
# City processed: tessalit
# City NOT found: rawannawi
# City processed: kota kinabalu
# City processed: rantepao
# City processed: san jose de buan
# City NOT found: kegayli
# City processed: vao
# City processed: chernyshevskiy
# City processed: finnsnes
# City NOT found: galgani
# City processed: kasongo-lunda
# City processed: vidim
# City processed: along
# City processed: tilichiki
# City processed: huntsville
# City processed: viedma
# City processed: yar-sale
# City processed: aykhal
# City processed: pascagoula
# City processed: honningsvag
# City processed: wiarton
# City processed: mitsamiouli
# City processed: brae
# City processed: saint-joseph
# City processed: bud
# City processed: mangan
# City processed: vila velha
# City processed: butembo
# City processed: hunterville
# City processed: damphu
# City processed: olafsvik
# City NOT found: viligili
# City processed: sur
# City processed: comodoro rivadavia
# City NOT found: linchuan
# City processed: camacha
# City processed: george town
# City processed: srikakulam
# City processed: byron bay
# City NOT found: haibowan
# City processed: great falls
# City NOT found: doctor pedro p. pena
# City processed: esmeraldas
# City processed: mezhova
# City processed: port blair
# City processed: imatra
# City processed: genhe
# City processed: biltine
# City processed: kloulklubed
# City processed: muncar
# City processed: saint george
# City processed: filingue
# City processed: mana
# City processed: hemsedal
# City processed: kushmurun
# City processed: hithadhoo
# City processed: lazaro cardenas
# City processed: wasco
# City processed: synya
# City processed: koryukivka
# City processed: saldanha
# City processed: itupiranga
# City processed: chirongui
# City processed: verkhneyarkeyevo
# City processed: trairi
# City processed: paracatu
# City processed: bandrele
# City processed: cadillac
# City NOT found: ozgon
# City processed: jatai
# City processed: scarborough
# City processed: progreso
# City processed: marawi
# City processed: scranton
# City processed: bolama
# City processed: kaliningrad
# City processed: sangar
# City processed: maroantsetra
# City processed: buraydah
# City processed: quatre cocos
# City processed: mizdah
# City processed: poum
# City processed: alofi
# City processed: huangmei
# City processed: kalabo
# City processed: kupang
# City processed: anadyr
# City NOT found: marcona
# City NOT found: dujuma
# City NOT found: cheuskiny
# City processed: batemans bay
# City processed: otane
# City processed: zakamensk
# City processed: manono
# City processed: lithakia
# City processed: umea
# City processed: taywarah
# City processed: bambous virieux
# City processed: egvekinot
# City processed: puerto rondon
# City processed: moose factory
# City processed: mecca
# City processed: dunedin
# City processed: cururupu
# City processed: evanton
# City processed: bardsir
# City processed: cierna nad tisou
# City processed: tabou
# City processed: xining
# City processed: berdigestyakh
# City processed: cayenne
# City NOT found: temaraia
# City processed: mnogovershinnyy
# City processed: jiwani
# City processed: maceio
# City processed: kyren
# City processed: longyan
# City processed: henties bay
# City processed: naze
# City processed: namibe
# City processed: seoul
# City processed: alice springs
# City processed: tamale
# City processed: beaumont
# City processed: longyearbyen
# City processed: pochutla
# City processed: orange cove
# City processed: santa rosalia
# City processed: pio ix
# City processed: luwuk
# City processed: pisco
# City processed: gourcy
# City processed: woodstock
# City NOT found: longlac
# City processed: pangkalanbuun
# City processed: ugoofaaru
# City processed: palu
# City processed: ajdabiya
# City processed: nagapattinam
# City processed: lander
# City processed: surt
# City processed: makakilo city
# City processed: berea
# City processed: inirida
# City processed: mama
# City processed: pandan
# City processed: bermejo
# City processed: dukat
# City processed: cocorit
# City processed: saint-georges
# City processed: rzhev
# City processed: tura
# City processed: dodoma
# City processed: ocos
# City processed: denpasar

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
Weather_DF = pd.DataFrame({"City": foundCities,
                           "Country": country,
                           "Temperature": temp,
                           "Humidity": humidity,
                           "Cloudiness": cloudiness,
                           "Windspeed":windSpeed,
                           "Latitude": lat,
                           "Longitude": lon,
                           "Date": date
                          })

# %%
#Windows desktop path
Weather_DF.to_csv(r'/Users/matth/OneDrive/Desktop/GitClones/python-api-challenge/output_data/Cities.csv', index = False)
#Macbook path
#Weather_DF.to_csv(r'/Users/md/Desktop/python-api-challenge/output_data/Cities.csv', index = False)
Weather_DF
# Out:
#            City Country  Temperature  Humidity  Cloudiness  Windspeed  \
# 0       ushuaia      AR        37.40        89          91       6.93
# 1    butaritari      KI        83.14        77          98      11.23
# 2       mataura      NZ        39.00        83          33       3.00
# 3       tsabong      BW        53.10        44           0       7.52
# 4       qaanaaq      GL        40.42        69          99       7.87
# ..          ...     ...          ...       ...         ...        ...
# 561       rzhev      RU        59.70        88          98       9.89
# 562        tura      IN        75.02        91           8       4.74
# 563      dodoma      TZ        66.20        68          20       9.17
# 564        ocos      GT        91.40        66          40       8.05
# 565    denpasar      ID        80.60       100          40      11.41
#
#      Latitude  Longitude        Date
# 0      -54.80     -68.30  1592688876
# 1        3.07     172.79  1592688876
# 2      -46.19     168.86  1592688877
# 3      -26.02      22.40  1592688877
# 4       77.48     -69.36  1592688877
# ..        ...        ...         ...
# 561     56.26      34.33  1592688919
# 562     25.52      90.22  1592688919
# 563     -6.17      35.74  1592688919
# 564     14.51     -92.19  1592688919
# 565     -8.65     115.22  1592688792
#
# [566 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
badHumidityDF = Weather_DF[(Weather_DF['Humidity'] > 100)]
badHumidityDF
# Out:
# Empty DataFrame
# Columns: [City, Country, Temperature, Humidity, Cloudiness, Windspeed, Latitude, Longitude, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
badHumidityDF.index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = Weather_DF.join(badHumidityDF, how='outer')
clean_city_data = Weather_DF.merge(badHumidityDF,on=index,inplace=False).query('index!=index')

# %%
# Extract relevant fields from the data frame
City_Data = Weather_DF[["City","Country", "Latitude", "Temperature", "Humidity", "Cloudiness", "Windspeed", "Date"]]

# Export the City_Data into a csv
#Windows path
City_Data.to_csv(r'/Users/matth/OneDrive/Desktop/GitClones/python-api-challenge/output_data/City_Data.csv', index = False)
#Macbook path
#City_Data.to_csv(r'/Users/md/Desktop/python-api-challenge/output_data/City_Data.csv', index = False)
City_Data.head()
# Out:
#          City Country  Latitude  Temperature  Humidity  Cloudiness  Windspeed  \
# 0     ushuaia      AR    -54.80        37.40        89          91       6.93
# 1  butaritari      KI      3.07        83.14        77          98      11.23
# 2     mataura      NZ    -46.19        39.00        83          33       3.00
# 3     tsabong      BW    -26.02        53.10        44           0       7.52
# 4     qaanaaq      GL     77.48        40.42        69          99       7.87
#
#          Date
# 0  1592688876
# 1  1592688876
# 2  1592688877
# 3  1592688877
# 4  1592688877

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#format the max date in the dataset as "runDate" for graph titles
endRunDate = City_Data["Date"].max()
runDate = datetime.utcfromtimestamp(endRunDate).strftime('%Y-%m-%d')

#set data to plot
x = City_Data["Latitude"]
y = City_Data["Temperature"]
plt.scatter(x,y)
#add gridlines
plt.grid()
#add titles and axis labels
plt.title(f"Latitude vs Temperature on {runDate}")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
#export as png
plt.savefig(f'../output_data/Latitude vs Temperature on {runDate}.png')
#display plot!
plt.show()

# %% [markdown]
# ### Latitude vs Temperature Scatter Plot Insights
#
# The scatter plot maps cities' temperature against their latitude.  Cities selected randomly.
# The arc of the scatter plot shows temperature increasing near the equator (Latitude 0) and dropping off further away. Given the run date of June 2020, the plot also skews higher temperatures to the right of the equator due to summer in the northern hemisphere.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#set data to plot; retain Latitude from previous plot as "x"
h = City_Data["Humidity"]
plt.scatter(x,h)
plt.title(f"Latitude vs Humidity on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig(f'../output_data/Latitude vs Humidity on {runDate}.png')
plt.show()

# %% [markdown]
# ### Latitude vs Humidity Scatter Plot Insights
#
# The scatter plot maps cities' humidity against their latitude.  Cities selected randomly.
#
# The result reveals no particular correlation between humidity and latitude.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
c = City_Data["Cloudiness"]
plt.scatter(x,c)
plt.title(f"Latitude vs Cloudiness on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig(f'../output_data/Latitude vs Cloudiness on {runDate}.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Latitude vs Cloudiness Scatter Plot Insights
#
# The scatter plot maps cities' cloudiness percent against their latitude.  Cities selected randomly.
#
# The result reveals no particular correlation between cloudiness and latitude. There may however be a slight bias towards round cloudiness percentages, given the groupings near each 10s line (ex: 40% cloudiness).

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
ws = City_Data["Windspeed"]
plt.scatter(x,ws)
plt.title(f"Latitude vs Windspeed on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Windspeed (mph)")
plt.savefig(f'../output_data/Latitude vs Windspeed on {runDate}.png')
plt.show()

# %% [markdown]
# ### Latitude vs Wind Speed Scatter Plot Insights
#
# The scatter plot maps cities' wind speed against their latitude.  Cities selected randomly.
#
# The result reveals no particular correlation between wind speed and latitude.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

#function to call is "linearRegression"
#variables are
# x_values: first set of data
# y_values: second set of data
# regEQplotX: where the linear regression equasion appears on the plot x line
# regEQplotY: where the linear regression equasion appears on the plot y line
# y_label: the y axis label of the plot (x label is always Latitude)

def linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f'The r-square is {rvalue}')
    print(line_eq)
    plt.annotate(line_eq,(regEQplotX,regEQplotY),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{y_label}')
    plt.grid()

# %%
# Create Northern and Southern Hemisphere DataFrames
#pull loc above and below the equator; note any cities directly on the equator (i.e. latitude = 0) are excluded
Northern_DF = Weather_DF.loc[Weather_DF["Latitude"] > 0]
Southern_DF = Weather_DF.loc[Weather_DF["Latitude"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set the data sets to compare
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Temperature"]
#tweak where the equation appears on the plot
regEQplotX = 0
regEQplotY = 40
#label the y axis
y_label = "Temperature (F)"
#give the title
plt.title(f'Northern Hemisphere Latitude vs Temp on {runDate}')
#run the function with all 5 variables
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
#save as a png to the neighboring output_data folder
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Temp on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.6832066822269389
# y = -0.5x + 89.33

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Temperature"]
regEQplotX = -25
regEQplotY = 40
y_label = "Temperature (F)"
plt.title(f'Southern Hemisphere Latitude vs Temp on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Temp on {runDate}.png')
plt.show()
# Out:
# The r-square is 0.7810599034722966
# y = 0.77x + 80.74

# %% [markdown]
# ### North/South Latitude vs TEMPERATURE Linear Regression Insights
#
# The scatter plot maps Northern and Southern cities' temperature against their latitude.  Cities selected randomly.
#
# The result reveals a strong correlation between distance from the equator temperature. The closer to the equator, the higher the temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Humidity"]
regEQplotX = 45
regEQplotY = 15
y_label = "Humidity (%)"
plt.title(f'Northern Hemisphere Latitude vs Humidity on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Humidity on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.06517863081603088
# y = -0.07x + 69.27

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Humidity"]
regEQplotX = -55
regEQplotY = 35
y_label = "Humidity (%)"
plt.title(f'Southern Hemisphere Latitude vs Humidity on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Humidity on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.13440802925869613
# y = -0.18x + 71.8

# %% [markdown]
# ### North/South Latitude vs HUMIDITY Linear Regression Insights
#
# The scatter plot maps Northern and Southern cities' humidity against their latitude.  Cities selected randomly.
#
# The result reveals no correlation between latitude and humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Cloudiness"]
regEQplotX = 0
regEQplotY = 25
y_label = "Cloudiness (%)"
plt.title(f'Northern Hemisphere Latitude vs Cloudiness on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Cloudiness on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.004682549349075001
# y = -0.01x + 51.95

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Cloudiness"]
regEQplotX = -55
regEQplotY = 60
y_label = "Cloudiness (%)"
plt.title(f'Southern Hemisphere Latitude vs Cloudiness on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Cloudiness on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.1472269548994391
# y = -0.4x + 34.64

# %% [markdown]
# ### North/South Latitude vs CLOUDINESS Linear Regression Insights
#
# The scatter plot maps Northern and Southern cities' cloudiness against their latitude.  Cities selected randomly.
#
# The result reveals no correlation between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Windspeed"]
regEQplotX = 35
regEQplotY = 25
y_label = "Wind Speed (MPH)"
plt.title(f'Northern Hemisphere Latitude vs Wind Speed on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Wind Speed on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.04421451915435909
# y = -0.01x + 8.65

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Windspeed"]
regEQplotX = -50
regEQplotY = 25
y_label = "Wind Speed (MPH)"
plt.title(f'Southern Hemisphere Latitude vs Wind Speed on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Wind Speed on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.01804807721603142
# y = -0.01x + 7.01

# %% [markdown]
# ### North/South Latitude vs WIND SPEED Linear Regression Insights
#
# The scatter plot maps Northern and Southern cities' wind speed against their latitude.  Cities selected randomly.
#
# The result reveals no correlation between latitude and wind speed.
